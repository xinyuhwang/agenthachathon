# %%
# first run installations and data download
# ! pip install -U llama-index llama-index-vector-stores-milvus pymilvus llama-index-llms-openai llama-index-readers-file
# ! mkdir -p './data/10k/'
# ! curl 'https://raw.githubusercontent.com/run-llama/llama_index/main/docs/examples/data/10k/uber_2021.pdf' -O 'data/10k/uber_2021.pdf'
# ! curl 'https://raw.githubusercontent.com/run-llama/llama_index/main/docs/examples/data/10k/lyft_2021.pdf' -O 'data/10k/lyft_2021.pdf'
# ! mv 'lyft_2021.pdf' 'uber_2021.pdf' './data/10k/'

# %%
from llama_index.core import (
    SimpleDirectoryReader,
    VectorStoreIndex,
    StorageContext,
    load_index_from_storage,
)
from llama_index.core.tools import QueryEngineTool, ToolMetadata

from pymilvus import connections
from llama_index.vector_stores.milvus import MilvusVectorStore

# %%
try:
    storage_context = StorageContext.from_defaults(
        persist_dir="./storage/lyft"
    )
    lyft_index = load_index_from_storage(storage_context)

    storage_context = StorageContext.from_defaults(
        persist_dir="./storage/uber"
    )
    uber_index = load_index_from_storage(storage_context)

    index_loaded = True
except:
    index_loaded = False

# %%
if not index_loaded:
    # load data
    lyft_docs = SimpleDirectoryReader(
        input_files=["./data/10k/lyft_2021.pdf"]
    ).load_data()
    uber_docs = SimpleDirectoryReader(
        input_files=["./data/10k/uber_2021.pdf"]
    ).load_data()

    # build index
    vector_store_lyft = MilvusVectorStore(dim=1536, collection_name="lyft", overwrite=True)
    vector_store_uber = MilvusVectorStore(dim=1536, collection_name="uber", overwrite=True)
    storage_context_lyft = StorageContext.from_defaults(vector_store=vector_store_lyft)
    storage_context_uber = StorageContext.from_defaults(vector_store=vector_store_uber)
    lyft_index = VectorStoreIndex.from_documents(lyft_docs, storage_context=storage_context_lyft)
    uber_index = VectorStoreIndex.from_documents(uber_docs, storage_context=storage_context_uber)

    # persist index
    lyft_index.storage_context.persist(persist_dir="./storage/lyft")
    uber_index.storage_context.persist(persist_dir="./storage/uber")
# Out:
# RPC error: [__internal_register], <MilvusException: (code=65535, message=empty grpc client: find no available rootcoord, check rootcoord state)>, <Time:{'RPC start': '2024-03-02 10:30:15.703147', 'RPC error': '2024-03-02 10:31:08.328612'}>
# Failed to create new connection using: cb91a5ef6aef4fc88ab7b2851260d393
# ---------------------------------------------------------------------------
# MilvusException                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[11], line 11
#      10 # build index
# ---> 11 vector_store_lyft = MilvusVectorStore(dim=1536, collection_name="lyft", overwrite=True)
#      12 vector_store_uber = MilvusVectorStore(dim=1536, collection_name="uber", overwrite=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/llama_index/vector_stores/milvus/base.py:141, in MilvusVectorStore.__init__(self, uri, token, collection_name, dim, embedding_field, doc_id_field, similarity_metric, consistency_level, overwrite, text_key, index_config, search_config, **kwargs)
#     140 # Connect to Milvus instance
# --> 141 self._milvusclient = MilvusClient(
#     142     uri=uri,
#     143     token=token,
#     144     **kwargs,  # pass additional arguments such as server_pem_path
#     145 )
#     146 # Delete previous collection if overwriting
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/milvus_client/milvus_client.py:59, in MilvusClient.__init__(self, uri, user, password, db_name, token, timeout, **kwargs)
#      57     self.tqdm = lambda x, disable: x
# ---> 59 self._using = self._create_connection(
#      60     uri, user, password, db_name, token, timeout=timeout, **kwargs
#      61 )
#      62 self.is_self_hosted = bool(utility.get_server_type(using=self._using) == "milvus")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/milvus_client/milvus_client.py:551, in MilvusClient._create_connection(self, uri, user, password, db_name, token, **kwargs)
#     550     logger.error("Failed to create new connection using: %s", using)
# --> 551     raise ex from ex
#     552 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/milvus_client/milvus_client.py:548, in MilvusClient._create_connection(self, uri, user, password, db_name, token, **kwargs)
#     547 try:
# --> 548     connections.connect(using, user, password, db_name, token, uri=uri, **kwargs)
#     549 except Exception as ex:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/orm/connections.py:414, in Connections.connect(self, alias, user, password, db_name, token, **kwargs)
#     412         kwargs["secure"] = True
# --> 414 connect_milvus(**kwargs, user=user, password=password, token=token, db_name=db_name)
#     415 return
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/orm/connections.py:365, in Connections.connect.<locals>.connect_milvus(**kwargs)
#     363 timeout = t if isinstance(t, (int, float)) else Config.MILVUS_CONN_TIMEOUT
# --> 365 gh._wait_for_channel_ready(timeout=timeout)
#     366 if kwargs.get("keep_alive", False):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/client/grpc_handler.py:151, in GrpcHandler._wait_for_channel_ready(self, timeout)
#     150 except Exception as e:
# --> 151     raise e from e
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/client/grpc_handler.py:144, in GrpcHandler._wait_for_channel_ready(self, timeout)
#     143     grpc.channel_ready_future(self._channel).result(timeout=timeout)
# --> 144     self._setup_identifier_interceptor(self._user, timeout=timeout)
#     145 except grpc.FutureTimeoutError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/client/grpc_handler.py:262, in GrpcHandler._setup_identifier_interceptor(self, user, timeout)
#     261 host = socket.gethostname()
# --> 262 self._identifier = self.__internal_register(user, host, timeout=timeout)
#     263 self._identifier_interceptor = interceptor.header_adder_interceptor(
#     264     ["identifier"], [str(self._identifier)]
#     265 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:135, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     134     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 135     raise e from e
#     136 except grpc.FutureTimeoutError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:131, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     130     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 131     return func(*args, **kwargs)
#     132 except MilvusException as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:170, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     169     self.set_onetime_request_id(req_id)
# --> 170 return func(self, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:110, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     109     else:
# --> 110         raise e from e
#     111 except Exception as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:74, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      73 try:
# ---> 74     return func(*args, **kwargs)
#      75 except grpc.RpcError as e:
#      76     # Reference: https://grpc.github.io/grpc/python/grpc.html#grpc-status-code
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:210, in upgrade_reminder.<locals>.handler(*args, **kwargs)
#     209 except Exception as e:
# --> 210     raise e from e
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:200, in upgrade_reminder.<locals>.handler(*args, **kwargs)
#     199 try:
# --> 200     return func(*args, **kwargs)
#     201 except grpc.RpcError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/client/grpc_handler.py:1785, in GrpcHandler.__internal_register(self, user, host, **kwargs)
#    1784 response = self._stub.Connect(request=req)
# -> 1785 check_status(response.status)
#    1786 return response.identifier
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/client/utils.py:54, in check_status(status)
#      53 if status.code != 0 or status.error_code != 0:
# ---> 54     raise MilvusException(status.code, status.reason, status.error_code)
#
# MilvusException: <MilvusException: (code=65535, message=empty grpc client: find no available rootcoord, check rootcoord state)>
#
# The above exception was the direct cause of the following exception:
#
# MilvusException                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[11], line 11
#      10 # build index
# ---> 11 vector_store_lyft = MilvusVectorStore(dim=1536, collection_name="lyft", overwrite=True)
#      12 vector_store_uber = MilvusVectorStore(dim=1536, collection_name="uber", overwrite=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/llama_index/vector_stores/milvus/base.py:141, in MilvusVectorStore.__init__(self, uri, token, collection_name, dim, embedding_field, doc_id_field, similarity_metric, consistency_level, overwrite, text_key, index_config, search_config, **kwargs)
#     140 # Connect to Milvus instance
# --> 141 self._milvusclient = MilvusClient(
#     142     uri=uri,
#     143     token=token,
#     144     **kwargs,  # pass additional arguments such as server_pem_path
#     145 )
#     146 # Delete previous collection if overwriting
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/milvus_client/milvus_client.py:59, in MilvusClient.__init__(self, uri, user, password, db_name, token, timeout, **kwargs)
#      57     self.tqdm = lambda x, disable: x
# ---> 59 self._using = self._create_connection(
#      60     uri, user, password, db_name, token, timeout=timeout, **kwargs
#      61 )
#      62 self.is_self_hosted = bool(utility.get_server_type(using=self._using) == "milvus")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/milvus_client/milvus_client.py:551, in MilvusClient._create_connection(self, uri, user, password, db_name, token, **kwargs)
#     550     logger.error("Failed to create new connection using: %s", using)
# --> 551     raise ex from ex
#     552 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/milvus_client/milvus_client.py:548, in MilvusClient._create_connection(self, uri, user, password, db_name, token, **kwargs)
#     547 try:
# --> 548     connections.connect(using, user, password, db_name, token, uri=uri, **kwargs)
#     549 except Exception as ex:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/orm/connections.py:414, in Connections.connect(self, alias, user, password, db_name, token, **kwargs)
#     412         kwargs["secure"] = True
# --> 414 connect_milvus(**kwargs, user=user, password=password, token=token, db_name=db_name)
#     415 return
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/orm/connections.py:365, in Connections.connect.<locals>.connect_milvus(**kwargs)
#     363 timeout = t if isinstance(t, (int, float)) else Config.MILVUS_CONN_TIMEOUT
# --> 365 gh._wait_for_channel_ready(timeout=timeout)
#     366 if kwargs.get("keep_alive", False):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/client/grpc_handler.py:151, in GrpcHandler._wait_for_channel_ready(self, timeout)
#     150 except Exception as e:
# --> 151     raise e from e
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/client/grpc_handler.py:144, in GrpcHandler._wait_for_channel_ready(self, timeout)
#     143     grpc.channel_ready_future(self._channel).result(timeout=timeout)
# --> 144     self._setup_identifier_interceptor(self._user, timeout=timeout)
#     145 except grpc.FutureTimeoutError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/client/grpc_handler.py:262, in GrpcHandler._setup_identifier_interceptor(self, user, timeout)
#     261 host = socket.gethostname()
# --> 262 self._identifier = self.__internal_register(user, host, timeout=timeout)
#     263 self._identifier_interceptor = interceptor.header_adder_interceptor(
#     264     ["identifier"], [str(self._identifier)]
#     265 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:135, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     134     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 135     raise e from e
#     136 except grpc.FutureTimeoutError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:131, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     130     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 131     return func(*args, **kwargs)
#     132 except MilvusException as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:170, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     169     self.set_onetime_request_id(req_id)
# --> 170 return func(self, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:110, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     109     else:
# --> 110         raise e from e
#     111 except Exception as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:74, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      73 try:
# ---> 74     return func(*args, **kwargs)
#      75 except grpc.RpcError as e:
#      76     # Reference: https://grpc.github.io/grpc/python/grpc.html#grpc-status-code
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:210, in upgrade_reminder.<locals>.handler(*args, **kwargs)
#     209 except Exception as e:
# --> 210     raise e from e
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:200, in upgrade_reminder.<locals>.handler(*args, **kwargs)
#     199 try:
# --> 200     return func(*args, **kwargs)
#     201 except grpc.RpcError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/client/grpc_handler.py:1785, in GrpcHandler.__internal_register(self, user, host, **kwargs)
#    1784 response = self._stub.Connect(request=req)
# -> 1785 check_status(response.status)
#    1786 return response.identifier
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/client/utils.py:54, in check_status(status)
#      53 if status.code != 0 or status.error_code != 0:
# ---> 54     raise MilvusException(status.code, status.reason, status.error_code)
#
# MilvusException: <MilvusException: (code=65535, message=empty grpc client: find no available rootcoord, check rootcoord state)>
#
# The above exception was the direct cause of the following exception:
#
# MilvusException                           Traceback (most recent call last)
# Cell In[11], line 11
#       6 uber_docs = SimpleDirectoryReader(
#       7     input_files=["./data/10k/uber_2021.pdf"]
#       8 ).load_data()
#      10 # build index
# ---> 11 vector_store_lyft = MilvusVectorStore(dim=1536, collection_name="lyft", overwrite=True)
#      12 vector_store_uber = MilvusVectorStore(dim=1536, collection_name="uber", overwrite=True)
#      13 storage_context_lyft = StorageContext.from_defaults(vector_store=vector_store_lyft)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/llama_index/vector_stores/milvus/base.py:141, in MilvusVectorStore.__init__(self, uri, token, collection_name, dim, embedding_field, doc_id_field, similarity_metric, consistency_level, overwrite, text_key, index_config, search_config, **kwargs)
#     138 similarity_metric = similarity_metrics_map.get(similarity_metric.lower(), "L2")
#     140 # Connect to Milvus instance
# --> 141 self._milvusclient = MilvusClient(
#     142     uri=uri,
#     143     token=token,
#     144     **kwargs,  # pass additional arguments such as server_pem_path
#     145 )
#     146 # Delete previous collection if overwriting
#     147 if overwrite and collection_name in self.client.list_collections():
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/milvus_client/milvus_client.py:59, in MilvusClient.__init__(self, uri, user, password, db_name, token, timeout, **kwargs)
#      56     logger.debug("tqdm not found")
#      57     self.tqdm = lambda x, disable: x
# ---> 59 self._using = self._create_connection(
#      60     uri, user, password, db_name, token, timeout=timeout, **kwargs
#      61 )
#      62 self.is_self_hosted = bool(utility.get_server_type(using=self._using) == "milvus")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/milvus_client/milvus_client.py:551, in MilvusClient._create_connection(self, uri, user, password, db_name, token, **kwargs)
#     549 except Exception as ex:
#     550     logger.error("Failed to create new connection using: %s", using)
# --> 551     raise ex from ex
#     552 else:
#     553     logger.debug("Created new connection using: %s", using)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/milvus_client/milvus_client.py:548, in MilvusClient._create_connection(self, uri, user, password, db_name, token, **kwargs)
#     546 using = uuid4().hex
#     547 try:
# --> 548     connections.connect(using, user, password, db_name, token, uri=uri, **kwargs)
#     549 except Exception as ex:
#     550     logger.error("Failed to create new connection using: %s", using)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/orm/connections.py:414, in Connections.connect(self, alias, user, password, db_name, token, **kwargs)
#     411         if parsed_uri.scheme == "https":
#     412             kwargs["secure"] = True
# --> 414     connect_milvus(**kwargs, user=user, password=password, token=token, db_name=db_name)
#     415     return
#     417 # 2nd Priority, connection configs from env
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/orm/connections.py:365, in Connections.connect.<locals>.connect_milvus(**kwargs)
#     362 t = kwargs.get("timeout")
#     363 timeout = t if isinstance(t, (int, float)) else Config.MILVUS_CONN_TIMEOUT
# --> 365 gh._wait_for_channel_ready(timeout=timeout)
#     366 if kwargs.get("keep_alive", False):
#     367     gh.register_state_change_callback(
#     368         ReconnectHandler(self, alias, kwargs_copy).reconnect_on_idle
#     369     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/client/grpc_handler.py:151, in GrpcHandler._wait_for_channel_ready(self, timeout)
#     146     raise MilvusException(
#     147         code=Status.CONNECT_FAILED,
#     148         message=f"Fail connecting to server on {self._address}. Timeout",
#     149     ) from e
#     150 except Exception as e:
# --> 151     raise e from e
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/client/grpc_handler.py:144, in GrpcHandler._wait_for_channel_ready(self, timeout)
#     142 try:
#     143     grpc.channel_ready_future(self._channel).result(timeout=timeout)
# --> 144     self._setup_identifier_interceptor(self._user, timeout=timeout)
#     145 except grpc.FutureTimeoutError as e:
#     146     raise MilvusException(
#     147         code=Status.CONNECT_FAILED,
#     148         message=f"Fail connecting to server on {self._address}. Timeout",
#     149     ) from e
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/client/grpc_handler.py:262, in GrpcHandler._setup_identifier_interceptor(self, user, timeout)
#     260 def _setup_identifier_interceptor(self, user: str, timeout: int = 10):
#     261     host = socket.gethostname()
# --> 262     self._identifier = self.__internal_register(user, host, timeout=timeout)
#     263     self._identifier_interceptor = interceptor.header_adder_interceptor(
#     264         ["identifier"], [str(self._identifier)]
#     265     )
#     266     self._final_channel = grpc.intercept_channel(
#     267         self._final_channel, self._identifier_interceptor
#     268     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:135, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     133     record_dict["RPC error"] = str(datetime.datetime.now())
#     134     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 135     raise e from e
#     136 except grpc.FutureTimeoutError as e:
#     137     record_dict["gRPC timeout"] = str(datetime.datetime.now())
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:131, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     129 try:
#     130     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 131     return func(*args, **kwargs)
#     132 except MilvusException as e:
#     133     record_dict["RPC error"] = str(datetime.datetime.now())
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:170, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     168 if req_id:
#     169     self.set_onetime_request_id(req_id)
# --> 170 return func(self, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:110, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     108         back_off = min(back_off * back_off_multiplier, max_back_off)
#     109     else:
# --> 110         raise e from e
#     111 except Exception as e:
#     112     raise e from e
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:74, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      72 while True:
#      73     try:
# ---> 74         return func(*args, **kwargs)
#      75     except grpc.RpcError as e:
#      76         # Reference: https://grpc.github.io/grpc/python/grpc.html#grpc-status-code
#      77         if e.code() in (
#      78             grpc.StatusCode.DEADLINE_EXCEEDED,
#      79             grpc.StatusCode.PERMISSION_DENIED,
#    (...)
#      83             grpc.StatusCode.RESOURCE_EXHAUSTED,
#      84         ):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:210, in upgrade_reminder.<locals>.handler(*args, **kwargs)
#     208     raise e from e
#     209 except Exception as e:
# --> 210     raise e from e
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/decorators.py:200, in upgrade_reminder.<locals>.handler(*args, **kwargs)
#     197 @functools.wraps(func)
#     198 def handler(*args, **kwargs):
#     199     try:
# --> 200         return func(*args, **kwargs)
#     201     except grpc.RpcError as e:
#     202         if e.code() == grpc.StatusCode.UNIMPLEMENTED:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/client/grpc_handler.py:1785, in GrpcHandler.__internal_register(self, user, host, **kwargs)
#    1783 req = Prepare.register_request(user, host)
#    1784 response = self._stub.Connect(request=req)
# -> 1785 check_status(response.status)
#    1786 return response.identifier
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymilvus/client/utils.py:54, in check_status(status)
#      52 def check_status(status: Status):
#      53     if status.code != 0 or status.error_code != 0:
# ---> 54         raise MilvusException(status.code, status.reason, status.error_code)
#
# MilvusException: <MilvusException: (code=65535, message=empty grpc client: find no available rootcoord, check rootcoord state)>

# %%
lyft_engine = lyft_index.as_query_engine(similarity_top_k=3)
uber_engine = uber_index.as_query_engine(similarity_top_k=3)

# %%
query_engine_tools = [
    QueryEngineTool(
        query_engine=lyft_engine,
        metadata=ToolMetadata(
            name="lyft_10k",
            description=(
                "Provides information about Lyft financials for year 2021. "
                "Use a detailed plain text question as input to the tool."
            ),
        ),
    ),
    QueryEngineTool(
        query_engine=uber_engine,
        metadata=ToolMetadata(
            name="uber_10k",
            description=(
                "Provides information about Uber financials for year 2021. "
                "Use a detailed plain text question as input to the tool."
            ),
        ),
    ),
]

# %%
from llama_index.core.agent import ReActAgent
from llama_index.llms.openai import OpenAI

# %%
llm = OpenAI(model="gpt-3.5-turbo-0613")

agent = ReActAgent.from_tools(
    query_engine_tools,
    llm=llm,
    verbose=True,
    # context=context
)

# %%
response = agent.chat("What was Lyft's revenue growth in 2021?")
print(str(response))
# Out:
# Thought: I can use the "lyft_10k" tool to find information about Lyft's revenue growth in 2021.
# Action: lyft_10k
# Action Input: {'input': "What was Lyft's revenue growth in 2021?"}
# Observation: Lyft's revenue increased by 36% in 2021 compared to the prior year.
# Thought: I have the information needed to answer the question.
# Answer: Lyft's revenue growth in 2021 was 36%.
# Lyft's revenue growth in 2021 was 36%.
